# %%
import pandas as pd
import glob
import xlrd
import openpyxl
import html5lib
import sys
sys.path.append(r"C:\\Users\\Garimahdi.Supandi\\Hexindo Case")
import reportCompiler as rc

# %%
html1 = r"E:\iseng\test.html"
html2 = r"E:\iseng\test - Copy.html"
html3 = r"E:\iseng\test - Copy (2).html"
html4 = r"E:\iseng\test - Copy (3).html"
html5 = r"E:\iseng\test - Copy (4).html"
html6 = r"E:\iseng\test - Copy (5).html"
html7 = r"E:\iseng\test - Copy (6).html"
html8 = r"E:\iseng\test - Copy (7).html"
html9 = r"E:\iseng\test - Copy (8).html"
html10 = r"E:\iseng\test - Copy (9).html"
html11 = r"E:\iseng\test - Copy (10).html"
html12 = r"E:\iseng\test - Copy (11).html"
html13 = r"E:\iseng\test - Copy (12).html"
html14 = r"E:\iseng\test - Copy (13).html"
html15 = r"E:\iseng\test - Copy (14).html"
html16 = r"E:\iseng\test - Copy (15).html"
html17 = r"E:\iseng\test - Copy (16).html"
html18 = r"E:\iseng\test - Copy (17).html"
html19 = r"E:\iseng\test - Copy (18).html"
html20 = r"E:\iseng\test - Copy (19).html"
html21 = r"E:\iseng\test - Copy (20).html"
html22 = r"E:\iseng\test - Copy (21).html"
html23 = r"E:\iseng\test - Copy (22).html"
html24 = r"E:\iseng\test - Copy (23).html"
html25 = r"E:\iseng\test - Copy (24).html"
html26 = r"E:\iseng\test - Copy (25).html"
html27 = r"E:\iseng\test - Copy (26).html"
html28 = r"E:\iseng\test - Copy (27).html"
html29 = r"E:\iseng\test - Copy (28).html"
html30 = r"E:\iseng\test - Copy (29).html"
html31 = r"E:\iseng\test - Copy (30).html"
html32 = r"E:\iseng\test - Copy (31).html"
html33 = r"E:\iseng\test - Copy (32).html"
html34 = r"E:\iseng\test - Copy (33).html"
html35 = r"E:\iseng\test - Copy (34).html"
html36 = r"E:\iseng\test - Copy (35).html"
html37 = r"E:\iseng\test - Copy (36).html"
html38 = r"E:\iseng\test - Copy (37).html"
html39 = r"E:\iseng\test - Copy (38).html"
html40 = r"E:\iseng\test - Copy (39).html"
html41 = r"E:\iseng\test - Copy (40).html"
html42 = r"E:\iseng\test - Copy (41).html"
html43 = r"E:\iseng\test - Copy (42).html"
html44 = r"E:\iseng\test - Copy (43).html"
html45 = r"E:\iseng\test - Copy (44).html"
html46 = r"E:\iseng\test - Copy (45).html"
html47 = r"E:\iseng\test - Copy (46).html"
html48 = r"E:\iseng\test - Copy (47).html"
html49 = r"E:\iseng\test - Copy (48).html"
html50 = r"E:\iseng\test - Copy (49).html"
html51 = r"E:\iseng\test - Copy (50).html"
html52 = r"E:\iseng\test - Copy (51).html"
html53 = r"E:\iseng\test - Copy (52).html"
html54 = r"E:\iseng\test - Copy (53).html"
html55 = r"E:\iseng\test - Copy (54).html"
html56 = r"E:\iseng\test - Copy (55).html"
html57 = r"E:\iseng\test - Copy (56).html"
html58 = r"E:\iseng\test - Copy (57).html"
html59 = r"E:\iseng\test - Copy (58).html"
html60 = r"E:\iseng\test - Copy (59).html"
html61 = r"E:\iseng\test - Copy (60).html"
html62 = r"E:\iseng\test - Copy (61).html"
html63 = r"E:\iseng\test - Copy (62).html"
html64 = r"E:\iseng\test - Copy (63).html"
html65 = r"E:\iseng\test - Copy (64).html"
html66 = r"E:\iseng\test - Copy (65).html"
html67 = r"E:\iseng\test - Copy (66).html"
html68 = r"E:\iseng\test - Copy (67).html"
html69 = r"E:\iseng\test - Copy (68).html"
html70 = r"E:\iseng\test - Copy (69).html"
html71 = r"E:\iseng\test - Copy (70).html"
html72 = r"E:\iseng\test - Copy (71).html"
html73 = r"E:\iseng\test - Copy (72).html"
html74 = r"E:\iseng\test - Copy (73).html"
html75 = r"E:\iseng\test - Copy (74).html"
html76 = r"E:\iseng\test - Copy (75).html"
html77 = r"E:\iseng\test - Copy (76).html"
html78 = r"E:\iseng\test - Copy (77).html"
html79 = r"E:\iseng\test - Copy (78).html"
html80 = r"E:\iseng\test - Copy (79).html"
html81 = r"E:\iseng\test - Copy (80).html"
html82 = r"E:\iseng\test - Copy (81).html"
html83 = r"E:\iseng\test - Copy (82).html"
html84 = r"E:\iseng\test - Copy (83).html"
html85 = r"E:\iseng\test - Copy (84).html"
html86 = r"E:\iseng\test - Copy (85).html"
html87 = r"E:\iseng\test - Copy (86).html"

# %%
artic16 = pd.read_html(html16)

# %%
artic1 = pd.read_html(html1, converters={'LoginName':str})[0]
artic2 = pd.read_html(html2, converters={'LoginName':str})[0]
artic3 = pd.read_html(html3, converters={'LoginName':str})[0]
artic4 = pd.read_html(html4, converters={'LoginName':str})[0]
artic5 = pd.read_html(html5, converters={'LoginName':str})[0]
artic6 = pd.read_html(html6, converters={'LoginName':str})[0]
artic7 = pd.read_html(html7, converters={'LoginName':str})[0]
artic8 = pd.read_html(html8, converters={'LoginName':str})[0]
artic9 = pd.read_html(html9, converters={'LoginName':str})[0]
artic10 = pd.read_html(html10, converters={'LoginName':str})[0]
artic11 = pd.read_html(html11, converters={'LoginName':str})[0]
artic12 = pd.read_html(html12, converters={'LoginName':str})[0]
artic13 = pd.read_html(html13, converters={'LoginName':str})[0]
artic14 = pd.read_html(html14, converters={'LoginName':str})[0]
artic15 = pd.read_html(html15, converters={'LoginName':str})[0]
artic16 = pd.read_html(html16, converters={'LoginName':str})[0]
artic17 = pd.read_html(html17, converters={'LoginName':str})[0]
artic18 = pd.read_html(html18, converters={'LoginName':str})[0]
artic19 = pd.read_html(html19, converters={'LoginName':str})[0]
artic20 = pd.read_html(html20, converters={'LoginName':str})[0]
artic21 = pd.read_html(html21, converters={'LoginName':str})[0]
artic22 = pd.read_html(html22, converters={'LoginName':str})[0]
artic23 = pd.read_html(html23, converters={'LoginName':str})[0]
artic24 = pd.read_html(html24, converters={'LoginName':str})[0]
artic25 = pd.read_html(html25, converters={'LoginName':str})[0]
artic26 = pd.read_html(html26, converters={'LoginName':str})[0]
artic27 = pd.read_html(html27, converters={'LoginName':str})[0]
artic28 = pd.read_html(html28, converters={'LoginName':str})[0]
artic29 = pd.read_html(html29, converters={'LoginName':str})[0]
artic30 = pd.read_html(html30, converters={'LoginName':str})[0]
artic31 = pd.read_html(html31, converters={'LoginName':str})[0]
artic32 = pd.read_html(html32, converters={'LoginName':str})[0]
artic33 = pd.read_html(html33, converters={'LoginName':str})[0]
artic34 = pd.read_html(html34, converters={'LoginName':str})[0]
artic35 = pd.read_html(html35, converters={'LoginName':str})[0]
artic36 = pd.read_html(html36, converters={'LoginName':str})[0]
artic37 = pd.read_html(html37, converters={'LoginName':str})[0]
artic38 = pd.read_html(html38, converters={'LoginName':str})[0]
artic39 = pd.read_html(html39, converters={'LoginName':str})[0]
artic40 = pd.read_html(html40, converters={'LoginName':str})[0]
artic41 = pd.read_html(html41, converters={'LoginName':str})[0]
artic42 = pd.read_html(html42, converters={'LoginName':str})[0]
artic43 = pd.read_html(html43, converters={'LoginName':str})[0]
artic44 = pd.read_html(html44, converters={'LoginName':str})[0]
artic45 = pd.read_html(html45, converters={'LoginName':str})[0]
artic46 = pd.read_html(html46, converters={'LoginName':str})[0]
artic47 = pd.read_html(html47, converters={'LoginName':str})[0]
artic48 = pd.read_html(html48, converters={'LoginName':str})[0]
artic49 = pd.read_html(html49, converters={'LoginName':str})[0]
artic50 = pd.read_html(html50, converters={'LoginName':str})[0]
artic51 = pd.read_html(html51, converters={'LoginName':str})[0]
artic52 = pd.read_html(html52, converters={'LoginName':str})[0]
artic53 = pd.read_html(html53, converters={'LoginName':str})[0]
artic54 = pd.read_html(html54, converters={'LoginName':str})[0]
artic55 = pd.read_html(html55, converters={'LoginName':str})[0]
artic56 = pd.read_html(html56, converters={'LoginName':str})[0]
artic57 = pd.read_html(html57, converters={'LoginName':str})[0]
artic58 = pd.read_html(html58, converters={'LoginName':str})[0]
artic59 = pd.read_html(html59, converters={'LoginName':str})[0]
artic60 = pd.read_html(html60, converters={'LoginName':str})[0]
artic61 = pd.read_html(html61, converters={'LoginName':str})[0]
artic62 = pd.read_html(html62, converters={'LoginName':str})[0]
artic63 = pd.read_html(html63, converters={'LoginName':str})[0]
artic64 = pd.read_html(html64, converters={'LoginName':str})[0]
artic65 = pd.read_html(html65, converters={'LoginName':str})[0]
artic66 = pd.read_html(html66, converters={'LoginName':str})[0]
artic67 = pd.read_html(html67, converters={'LoginName':str})[0]
artic68 = pd.read_html(html68, converters={'LoginName':str})[0]
artic69 = pd.read_html(html69, converters={'LoginName':str})[0]
artic70 = pd.read_html(html70, converters={'LoginName':str})[0]
artic71 = pd.read_html(html71, converters={'LoginName':str})[0]
artic72 = pd.read_html(html72, converters={'LoginName':str})[0]
artic73 = pd.read_html(html73, converters={'LoginName':str})[0]
artic74 = pd.read_html(html74, converters={'LoginName':str})[0]
artic75 = pd.read_html(html75, converters={'LoginName':str})[0]
artic76 = pd.read_html(html76, converters={'LoginName':str})[0]
artic77 = pd.read_html(html77, converters={'LoginName':str})[0]
artic78 = pd.read_html(html78, converters={'LoginName':str})[0]
artic79 = pd.read_html(html79, converters={'LoginName':str})[0]
artic80 = pd.read_html(html80, converters={'LoginName':str})[0]
artic81 = pd.read_html(html81, converters={'LoginName':str})[0]
artic82 = pd.read_html(html82, converters={'LoginName':str})[0]
artic83 = pd.read_html(html83, converters={'LoginName':str})[0]
artic84 = pd.read_html(html84, converters={'LoginName':str})[0]
artic85 = pd.read_html(html85, converters={'LoginName':str})[0]
artic86 = pd.read_html(html86, converters={'LoginName':str})[0]
artic87 = pd.read_html(html87, converters={'LoginName':str})[0]

# %%
a1 = rc.mergeData(
    artic1,
    artic2,
    artic3,
    artic4,
    artic5,
    artic6,
    artic7,
    artic8,
    artic9,
    artic10
)
a2 = rc.mergeData(
    artic11,
    artic12,
    artic13,
    artic14,
    artic15,
    artic16,
    artic17,
    artic18,
    artic19,
    artic20
)
a3 = rc.mergeData(
    artic21,
    artic22,
    artic23,
    artic24,
    artic25,
    artic26,
    artic27,
    artic28,
    artic29,
    artic30
)
a4 = rc.mergeData(
    artic31,
    artic32,
    artic33,
    artic34,
    artic35,
    artic36,
    artic37,
    artic38,
    artic39,
    artic40
)
a5 = rc.mergeData(
    artic41,
    artic42,
    artic43,
    artic44,
    artic45,
    artic46,
    artic47,
    artic48,
    artic49,
    artic50
)
a6 = rc.mergeData(
    artic51,
    artic52,
    artic53,
    artic54,
    artic55,
    artic56,
    artic57,
    artic58,
    artic59,
    artic60
)
a7 = rc.mergeData(
    artic61,
    artic62,
    artic63,
    artic64,
    artic65,
    artic66,
    artic67,
    artic68,
    artic69,
    artic70
)
a8 = rc.mergeData(
    artic81,
    artic82,
    artic83,
    artic84,
    artic85,
    artic86,
    artic87
)

# %%
artic_mix = rc.mergeData(
    a1,
    a2,
    a3,
    a4,
    a5,
    a6,
    a7,
    a8
)

# %%
am = list(artic_mix.columns)
am
artic_mix.drop(columns=am[5], inplace=True)
artic_mix.to_excel('E:\iseng\compiled_table_oss.xlsx',index=False)
